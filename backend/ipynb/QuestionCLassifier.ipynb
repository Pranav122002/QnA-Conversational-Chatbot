# %% [markdown]
# # Question Classification

# %%
import pickle
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import csv

# %%
def read_csv_to_list(filename):
    questions = []
    with open(filename, 'r', encoding='utf-8') as file:
        csv_reader = csv.reader(file)
        for row in csv_reader:
            if len(row) > 0:  
                questions.append(row[0])  
    return questions

# %%
filename_Para = "../datasets/QnA_Para.csv"
questions_Para = read_csv_to_list(filename_Para)
questions_Para
# Out:
# ['What is the history of the college?',
#  'Describe the history of the college',
#  'history of the Fr. CRIT',
#  ' history of the college?',
#  'What is Vision of your college?',
#  'vision of college',
#  'vision of the Fr. CRIT',
#  'Descibe the vision of college',
#  'What is Mission of your college?',
#  'mission of Fr. CRIT',
#  'mission of college',
#  'describe the mission of college',
#  'Who is Managing Director of your college?',
#  'MD of college',
#  'MD of Fr. CRIT',
#  'Managing Director of Fr. CRIT',
#  'Who is the chairman of your college?',
#  'chairman of college',
#  'chairman of Fr. CRIT',
#  'Who is vice-chairman of your college?',
#  'vice chairman of college',
#  'vice chairman of Fr. CRIT',
#  'Who is the treasurer of your college?',
#  'treasurer of college',
#  'treasurer of Fr. CRIT',
#  'Who is the Secretary of your college?',
#  'secretary of college',
#  'secretary of Fr. CRIT',
#  'Who is the Member of your college?',
#  'Who is the Principal of your college?',
#  'principal of college',
#  'principal of Fr. CRIT',
#  'Tell me about Principal?',
#  'qualification of principal',
#  'Email ID of principal?',
#  'How many departments are there ?',
#  'number of departments in Fr. CRIT',
#  'no. of departments in college',
#  'What are department present in college?',
#  'which departments exist?',
#  'departments in Fr. CRIT',
#  'Tell me about College?',
#  'describe the college',
#  'describe Fr. CRIT',
#  'elaborate about college',
#  'What is the intake capacity of computer department ?',
#  'annual intake for computer',
#  'number of seats in computer department',
#  'availability in computer',
#  'annual intake for IT',
#  'number of seats in IT department',
#  'availability in IT',
#  'What is the intake capacity of I.T department ?',
#  'What is the intake capacity of E.X.T.C. department ?',
#  'annual intake for EXTC',
#  'number of seats in EXTC department',
#  'availability in EXTC',
#  'What is the intake capacity of Mechanical department ?',
#  'annual intake for mechanical',
#  'number of seats in mechanical department',
#  'availability in mechanical ',
#  'What is the intake capacity of Electrical department ?',
#  'annual intake for electrical',
#  'number of seats in electrical department',
#  'availability in electrical',
#  'Tell me about computer department?',
#  'describe computer department',
#  'elaborate on computer department',
#  'vision of computer department',
#  'describe vision of computer department',
#  'elaborate on vision for computer department ',
#  'What is the vision of computer department?',
#  'mission of computer department',
#  'describe mission of computer department',
#  'elaborate on mission for computer department ',
#  'What is the mission of computer department?',
#  'Location of college?',
#  'where is Fr. CRIT located?',
#  'college situated at?',
#  'location of Fr. CRIT',
#  'Minority seats?',
#  'minority quota in college',
#  'minority seats in Fr. CRIT',
#  'minority status',
#  'placement ?',
#  'placement cell website',
#  'placement information',
#  'placements i Fr. CRIT',
#  'placement in college',
#  'phone ?',
#  'admission enquiry number',
#  'mobile no.',
#  'enquiry number',
#  'placement cell?',
#  'placement group in college',
#  'placement facility in college',
#  'placement cell in Fr. CRIT',
#  'placement officer?',
#  'placement officer of college',
#  'placement officer of Fr. CRIT',
#  'library?',
#  'library facility',
#  'library in college',
#  'library in Fr. CRIT',
#  'honors / minors in computer department?',
#  'honors / minors in computer ?',
#  'honors / minors in computer department  in college?',
#  'honors / minors in computer department? in Fr. CRIT',
#  'honors / minors in IT department?',
#  'honors / minors in IT ?',
#  'honors / minors in IT department in college?',
#  'honors / minors in IT departmentin Fr. CRIT?',
#  'honors / minors in mechanical department?',
#  'honors / minors in mechanical ?',
#  'honors / minors in mechanical department in college?',
#  'honors / minors in mechanical department in Fr. CRIT?',
#  'honors / minors in electrical department?',
#  'honors / minors in electrical ?',
#  'honors / minors in electrical department in college?',
#  'honors / minors in electrical department in Fr. CRIT?',
#  'honors / minors in EXTC department?',
#  'honors / minors in EXTC ?',
#  'honors / minors in EXTC department in college?',
#  'honors / minors in EXTC department in Fr. CRIT?',
#  'Dean academics?',
#  'Dean academics in college',
#  'Dean academics for Fr.CRIT',
#  'Dean Student Affairs?',
#  'Dean Student Affairs in college',
#  'Dean Student Affairs in Fr. CRIT',
#  'Dean R & D?',
#  'Dean R & D in college',
#  'Dean R & D in Fr. CRIT',
#  'Dean PG Studies?',
#  'Dean PG Studies in college',
#  'Dean PG Studies in Fr. CRIT',
#  'Dean Faculties? ',
#  'Dean Faculties in college',
#  'Dean Faculties in Fr. CRIT',
#  'Student Council?',
#  'student council in college',
#  'student council of Fr. CRIT',
#  'describe the student council',
#  'FACES?',
#  'intra collegiate fest',
#  'sports fest',
#  'techno fest',
#  'technical fest',
#  'inter collegiate techno fest',
#  'Eta Max?',
#  'Student Clubs?',
#  'student clubs in college',
#  'Student Clubs in Fr. CRIT',
#  'Infrastructure?',
#  'Infrastructure in college',
#  'Infrastructure in Fr. CRIT',
#  'ragging / anti-ragging?',
#  'anti ragging committee',
#  'ragging in college',
#  'ragging in Fr. CRIT',
#  'library website?',
#  'what is the institute roadmap?',
#  'Trustees of the college?',
#  'HOD of Computer department?',
#  'who is the Head of the computer department? ',
#  'Assistant HOD of computer department?',
#  'Who is the assistant head of the computer department? ',
#  'HOD of Mechanical department?',
#  'who is the Head of the Mechanical department? ',
#  'Assistant HOD of Mechanical department?',
#  'Who is the assistant head of the Mechanical department? ',
#  'HOD of EXTC department?',
#  'who is the Head of the EXTC department? ',
#  'Assistant HOD of EXTC department?',
#  'Who is the assistant head of the EXTC department? ',
#  'HOD of Electrical department?',
#  'who is the Head of the electrical department? ',
#  'Assistant HOD of electrical department?',
#  'Who is the assistant head of the electrical department? ',
#  'HOD of IT department?',
#  'who is the Head of the IT department? ',
#  'Assistant HOD of IT department?',
#  'Who is the assistant head of the IT department? ',
#  'HOD of Humanities department?',
#  'who is the Head of the Humanities department? ',
#  'Assistant HOD of Humanities department?',
#  'Who is the assistant head of the Humanities department? ',
#  'Dean students and alumni? ',
#  'Dean students and alumni in college',
#  'Dean students and alumni in Fr. CRIT',
#  'Associate Dean academics? ',
#  'Associate Dean academics in college',
#  'Associate Dean academics in Fr. CRIT',
#  'Associate Dean R & D and industry Liasoning? ',
#  'Associate Dean R & D and industry Liasoning in college',
#  'Associate Dean R & D and industry Liasoning in Fr. CRIT',
#  'Associate Dean Admin and Faculty ? ',
#  'Associate Dean Admin and Faculty in college',
#  'Associate Dean Admin and Faculty in Fr. CRIT',
#  'Associate Dean Students and alumni? ',
#  'Associate Dean Admin and Faculty in college',
#  'Associate Dean Admin and Faculty in Fr. CRIT',
#  'What are the different student clubs in college?',
#  'Different student clubs?',
#  'What are the different professional bodies present in the college?',
#  'Professional bodies in Fr.CRIT',
#  'NSS unit in college?',
#  'Last year report for the NSS unit',
#  'Is there direct second year admissions in the college?',
#  'Assistant Placement Officer',
#  'Who are the Assistant Placement Officer in Fr.CRIT?',
#  'What is the fee payment link for Fr.CRIT?',
#  'Fee payment link']

# %%
filename_Table = "../datasets/QnA_Table.csv"
questions_Table = read_csv_to_list(filename_Table)
questions_Table
# Out:
# ['What is sum of all packages?',
#  'What is average of all packages?',
#  'What is count of all packages?',
#  'What is highest of all packages?',
#  'Which company has highest of all packages?',
#  'Which company has highest package?',
#  'Which company has lowest package?',
#  'What is maximum package?',
#  'What is max package?',
#  'What is lowest package?',
#  'What is least package?',
#  'What is minimum package?',
#  'Which company gives highest package?',
#  'Which company gives lowest package?',
#  'Which company has highest number of students placed?',
#  'Which company has lowest number of students placed?',
#  'Which company has least number of students placed?',
#  'Which companies have same package?',
#  'What is the package of TCS?',
#  'What is the package of Jio?',
#  'What is the package of LTFS?',
#  'What is the package of Aurionpro?',
#  'What is the package of Seclore?',
#  'What is the package of Accenture?',
#  'What is the package of students placed in Jio?',
#  'What is the package of students placed in Seclore?',
#  'What is the package of students placed in Accenture?',
#  'What is the package of students placed in LTFS?',
#  'What is the package of students placed in Aurionpro?',
#  'What is the package of students placed in TCS?',
#  'How many students are placed in TCS?',
#  'How many students are placed in Jio?',
#  'How many students are placed in LTFS?',
#  'How many students are placed in Aurionpro?',
#  'How many students are placed in Accenture?',
#  'How many students are placed in Seclore?',
#  'Who has lesser package than Infosys?',
#  'Who has lesser package than Jio?',
#  'Who has lesser package than Accenture?',
#  'Who has lesser package than Aurionpro?',
#  'Which company has lesser package than Infosys?',
#  'Which company has lesser package than Jio?',
#  'Which company has lesser package than Accenture?',
#  'Which company has lesser package than Aurionpro?',
#  'Who has greater package than Jio?',
#  'Who has greater package than TCS?',
#  'Who has greater package than LTFS?',
#  'Who has greater package than Seclore?',
#  'Which company has greater package than Jio?',
#  'Which company has greater package than TCS?',
#  'Which company has greater package than LTFS?',
#  'Which company has greater package than Seclore?',
#  'Number of students placed in Accenture from Mechanical Department in year 2023?',
#  'Number of students placed in Accenture from Mechanical Department in year 2022?',
#  'Number of students placed in Accenture from Mechanical Department in year 2021?',
#  'Number of students placed in Accenture from Computer Department in year 2023?',
#  'Number of students placed in Accenture from Computer Department in year 2022?',
#  'Number of students placed in Accenture from Computer Department in year 2021?',
#  'Number of students placed in Accenture from IT Department in year 2023?',
#  'Number of students placed in Accenture from IT Department in year 2022?',
#  'Number of students placed in Accenture from IT Department in year 2021?',
#  'Number of students placed in Accenture from Mechanical in year 2023?',
#  'Number of students placed in Accenture from Mechanical in year 2022?',
#  'Number of students placed in Accenture from Mechanical in year 2021?',
#  'Number of students placed in Accenture from Computer in year 2023?',
#  'Number of students placed in Accenture from Computer in year 2022?',
#  'Number of students placed in Accenture from Computer in year 2021?',
#  'Number of students placed in Accenture from IT in year 2023?',
#  'Number of students placed in Accenture from IT in year 2022?',
#  'Number of students placed in Accenture from IT in year 2021?',
#  'How many students are placed in Accenture from Mechanical Department in year 2023?',
#  'How many students are placed in Accenture from Mechanical Department in year 2022?',
#  'How many students are placed in Accenture from Mechanical Department in year 2021?',
#  'How many students are placed in Accenture from Computer Department in year 2023?',
#  'How many students are placed in Accenture from Computer Department in year 2022?',
#  'How many students are placed in Accenture from Computer Department in year 2021?',
#  'How many students are placed in Accenture from IT Department in year 2023?',
#  'How many students are placed in Accenture from IT Department in year 2022?',
#  'How many students are placed in Accenture from IT Department in year 2021?',
#  'How many students are placed in Accenture from Mechanical in year 2023?',
#  'How many students are placed in Accenture from Mechanical in year 2022?',
#  'How many students are placed in Accenture from Mechanical in year 2021?',
#  'How many students are placed in Accenture from Computer in year 2023?',
#  'How many students are placed in Accenture from Computer in year 2022?',
#  'How many students are placed in Accenture from Computer in year 2021?',
#  'How many students are placed in Accenture from IT in year 2023?',
#  'How many students are placed in Accenture from IT in year 2022?',
#  'How many students are placed in Accenture from IT in year 2021?',
#  'Total number of students placed in TCS in year 2023?',
#  'Total number of students placed in TCS in year 2022?',
#  'Total number of students placed in TCS in year 2021?',
#  'Number of students placed in Accenture from Mechanical Department in 2023?',
#  'Number of students placed in Accenture from Mechanical Department in 2022?',
#  'Number of students placed in Accenture from Mechanical Department in 2021?',
#  'Number of students placed in Accenture from Computer Department in 2023?',
#  'Number of students placed in Accenture from Computer Department in 2022?',
#  'Number of students placed in Accenture from Computer Department in 2021?',
#  'Number of students placed in Accenture from IT Department in 2023?',
#  'Number of students placed in Accenture from IT Department in 2022?',
#  'Number of students placed in Accenture from IT Department in 2021?',
#  'Number of students placed in Accenture from Mechanical in 2023?',
#  'Number of students placed in Accenture from Mechanical in 2022?',
#  'Number of students placed in Accenture from Mechanical in 2021?',
#  'Number of students placed in Accenture from Computer in 2023?',
#  'Number of students placed in Accenture from Computer in 2022?',
#  'Number of students placed in Accenture from Computer in 2021?',
#  'Number of students placed in Accenture from IT in 2023?',
#  'Number of students placed in Accenture from IT in 2022?',
#  'Number of students placed in Accenture from IT in 2021?',
#  'How many students are placed in Accenture from Mechanical Department in 2023?',
#  'How many students are placed in Accenture from Mechanical Department in 2022?',
#  'How many students are placed in Accenture from Mechanical Department in 2021?',
#  'How many students are placed in Accenture from Computer Department in 2023?',
#  'How many students are placed in Accenture from Computer Department in 2022?',
#  'How many students are placed in Accenture from Computer Department in 2021?',
#  'How many students are placed in Accenture from IT Department in 2023?',
#  'How many students are placed in Accenture from IT Department in 2022?',
#  'How many students are placed in Accenture from IT Department in 2021?',
#  'How many students are placed in Accenture from Mechanical in 2023?',
#  'How many students are placed in Accenture from Mechanical in 2022?',
#  'How many students are placed in Accenture from Mechanical in 2021?',
#  'How many students are placed in Accenture from Computer in 2023?',
#  'How many students are placed in Accenture from Computer in 2022?',
#  'How many students are placed in Accenture from Computer in 2021?',
#  'How many students are placed in Accenture from IT in 2023?',
#  'How many students are placed in Accenture from IT in 2022?',
#  'How many students are placed in Accenture from IT in 2021?',
#  'Total number of students placed in TCS in 2023?',
#  'Total number of students placed in TCS in 2022?',
#  'Total number of students placed in TCS in 2021?',
#  'Number of students placed in TCS from Mechanical Department in year 2023?',
#  'Number of students placed in TCS from Mechanical Department in year 2022?',
#  'Number of students placed in TCS from Mechanical Department in year 2021?',
#  'Number of students placed in TCS from Computer Department in year 2023?',
#  'Number of students placed in TCS from Computer Department in year 2022?',
#  'Number of students placed in TCS from Computer Department in year 2021?',
#  'Number of students placed in TCS from IT Department in year 2023?',
#  'Number of students placed in TCS from IT Department in year 2022?',
#  'Number of students placed in TCS from IT Department in year 2021?',
#  'How many students are placed in TCS from Mechanical Department in year 2023?',
#  'How many students are placed in TCS from Mechanical Department in year 2022?',
#  'How many students are placed in TCS from Mechanical Department in year 2021?',
#  'How many students are placed in TCS from Computer Department in year 2023?',
#  'How many students are placed in TCS from Computer Department in year 2022?',
#  'How many students are placed in TCS from Computer Department in year 2021?',
#  'How many students are placed in TCS from IT Department in year 2023?',
#  'How many students are placed in TCS from IT Department in year 2022?',
#  'How many students are placed in TCS from IT Department in year 2021?',
#  'Total number of students placed in TCS in year 2023?',
#  'Total number of students placed in TCS in year 2022?',
#  'Total number of students placed in TCS in year 2021?',
#  '  ']

# %%
labels_Para = ["Para"] * len(questions_Para)
labels_Table = ["Table"] * len(questions_Table)

# %%
questions = questions_Para + questions_Table
labels = labels_Para + labels_Table

# %%
X_train, X_test, y_train, y_test = train_test_split(questions, labels, test_size=0.2, random_state=42)

# %%
vectorizer = CountVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
classifier = LogisticRegression(max_iter=1000)
classifier.fit(X_train_vec, y_train)

with open('../models/classifier_model.pkl', 'wb') as f:
    pickle.dump((classifier, vectorizer), f)

# %%
with open('../models/classifier_model.pkl', 'rb') as f:
    classifier, vectorizer = pickle.load(f)

# %%
question = "What is package?"
question_vec = vectorizer.transform([question])
predicted_model = classifier.predict(question_vec)[0]
print("Predicted model:", predicted_model)
# Out:
# Predicted model: Table

# %%
questions = ["What is highest package?", "package?", "How does it work?","What is package of Facebook?", "Why is it important?"]
question_vec = vectorizer.transform(questions)
predicted_models = classifier.predict(question_vec)
print("Predicted models:", predicted_models)
# Out:
# Predicted models: ['Table' 'Para' 'Para' 'Table' 'Para']
